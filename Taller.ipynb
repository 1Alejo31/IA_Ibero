# %%
#Importacion de librerias
import os
import pandas as pd
import numpy as np

#Leer la bd
url = 'C:\\Users\\alejo\\OneDrive\\Escritorio\\IA\\Unidad1\\Forbes-Global-2000-List-2023-Someka-Excel-Template-V1-Free-Version.xlsx'

#Definiendo los nombres de las columnas
nombres = ['Rango', 'Empresa', 'Pais', 'Ventas', 'Ganancias', 'Activos', 'Valor de mercado']

#leer la base de datos, no se tiene encuenta el headerm y se asignan los nombres de las columnas
df = pd.read_excel(url, header=None, names=nombres)

#Elimina las filas que contengan NaN o sean vacias
df = df.dropna()

#Mostrar la bd
df
# Out:
#     Rango                                   Empresa           Pais  \
# NaN  Rank                              Company Name        Country
# NaN     1                            JPMorgan Chase  United States
# NaN     2  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia
# NaN     3                                      ICBC          China
# NaN     4                   China Construction Bank          China
# ..    ...                                       ...            ...
# NaN  1996                                Alfa Laval         Sweden
# NaN  1996                                       Gap  United States
# NaN  1996                                  Yes Bank          India
# NaN  1999                                 BEKB-BCBE    Switzerland
# NaN  1999                                     Ipsen         France
#
#                  Ventas             Ganancias              Activos  \
# NaN  Sales\n($millions)  Profits\n($millions)  Assets\n($millions)
# NaN              179930                 41800              3744300
# NaN              589470                156360               660990
# NaN              216770                 52470              6116820
# NaN              203080                 48250              4977480
# ..                  ...                   ...                  ...
# NaN                5350                 489.5                 7820
# NaN               15620                  -202                11390
# NaN                3340                  91.6                43220
# NaN                 556                 167.1                42970
# NaN                3180                 681.7                 5990
#
#                        Valor de mercado
# NaN  Market Value \nAs of 05/05/23 ($m)
# NaN                              399590
# NaN                           2055220.0
# NaN                              203010
# NaN                              172990
# ..                                  ...
# NaN                               15600
# NaN                                3170
# NaN                                5600
# NaN                                2490
# NaN                               10210
#
# [2001 rows x 7 columns]

# %%
#Mostrar la bd
df
# Out:
#            Rango                                 Empresa  \
# NaN          NaN                                     NaN
# NaN          NaN                       SOMEKA INFO LISTS
# NaN          NaN  FORBES GLOBAL 2000 LIST - 2023 VERSION
# NaN          NaN                                     NaN
# NaN  DISCLAIMER:                                     NaN
# ..           ...                                     ...
# NaN         1996                              Alfa Laval
# NaN         1996                                     Gap
# NaN         1996                                Yes Bank
# NaN         1999                               BEKB-BCBE
# NaN         1999                                   Ipsen
#
#                                                   Pais Ventas Ganancias  \
# NaN                                                NaN    NaN       NaN
# NaN                                                NaN    NaN       NaN
# NaN                                                NaN    NaN       NaN
# NaN                                                NaN    NaN       NaN
# NaN  This list is officially published by Forbes Ma...    NaN       NaN
# ..                                                 ...    ...       ...
# NaN                                             Sweden   5350     489.5
# NaN                                      United States  15620      -202
# NaN                                              India   3340      91.6
# NaN                                        Switzerland    556     167.1
# NaN                                             France   3180     681.7
#
#     Activos Valor de mercado
# NaN     NaN              NaN
# NaN     NaN              NaN
# NaN     NaN              NaN
# NaN     NaN              NaN
# NaN     NaN              NaN
# ..      ...              ...
# NaN    7820            15600
# NaN   11390             3170
# NaN   43220             5600
# NaN   42970             2490
# NaN    5990            10210
#
# [2008 rows x 7 columns]

# %%
#ver la cantidad de registros
df.shape
# Out:
# (2008, 7)

# %%
# Imprimir información sobre el DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2008 entries, nan to nan
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rango             2002 non-null   object
#  1   Empresa           2003 non-null   object
#  2   Pais              2003 non-null   object
#  3   Ventas            2002 non-null   object
#  4   Ganancias         2001 non-null   object
#  5   Activos           2001 non-null   object
#  6   Valor de mercado  2001 non-null   object
# dtypes: object(7)
# memory usage: 125.5+ KB
